# %% [markdown]
# # Avacado Project

# %%
import pandas as pd
import numpy as np
import csv

df=pd.read_csv("C:/Users/hp/Datascience/avocado.csv")
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df["type"].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %%
df["year"].unique()
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df["type"].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
df.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.Date= pd.to_datetime(df.Date)
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
#Label Encoding
import pandas as pd
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df["type"]=LE.fit_transform(df["type"])
df["region"]=LE.fit_transform(df["region"])
df.head()
# Out:
#         Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0 2015-12-27          1.33     11.070344  6.944801  10.905146  3.895080
# 1 2015-12-20          1.35     10.912867  6.515127  10.706381  4.083115
# 2 2015-12-13          0.93     11.680313  6.679222  11.600485  4.879007
# 3 2015-12-06          1.08     11.277116  7.032624  11.184108  4.298373
# 4 2015-11-29          1.28     10.840377  6.848515  10.688288  4.340944
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# 0    9.070833    9.060055    4.545951      8.04155     0  2015       0
# 1    9.159737    9.149429    4.589955      8.04155     0  2015       0
# 2    9.005325    8.992584    4.645736      8.04155     0  2015       0
# 3    8.667708    8.644425    4.903495      8.04155     0  2015       0
# 4    8.729874    8.697389    5.291746      8.04155     0  2015       0

# %%
np.where(df["XLarge Bags"]==0)
# Out:
# (array([    0,     1,     2, ..., 18246, 18247, 18248], dtype=int64),)

# %%
df.loc[df["XLarge Bags"]==0.0]
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %%
df["XLarge Bags"]=df["XLarge Bags"].replace(0.0,np.mean(df["XLarge Bags"]))

df
# Out:
#             Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0     2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1     2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2     2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3     2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4     2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# ...          ...           ...           ...      ...        ...     ...
# 18244 2018-02-04          1.63      17074.83  2046.96    1529.20    0.00
# 18245 2018-01-28          1.71      13888.04  1191.70    3431.50    0.00
# 18246 2018-01-21          1.87      13766.76  1191.92    2452.79  727.94
# 18247 2018-01-14          1.93      16205.22  1527.63    2981.04  727.01
# 18248 2018-01-07          1.62      17489.58  2894.77    2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# ...

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          type  \
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    5157.291024      0.499918
# ...

# %%
import seaborn as sns
sns.barplot(x="year",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
sns.barplot(x="type",y="AveragePrice",data=df)
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %%
df["year"].unique()
# Out:
# array([2015, 2016, 2017, 2018], dtype=int64)

# %%
df.hist(figsize=(20,20),grid=True,layout=(4,5))
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>,
#         <AxesSubplot:title={'center':'4225'}>],
#        [<AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>,
#         <AxesSubplot:title={'center':'Small Bags'}>,
#         <AxesSubplot:title={'center':'Large Bags'}>,
#         <AxesSubplot:title={'center':'XLarge Bags'}>],
#        [<AxesSubplot:title={'center':'type'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'region'}>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
#Data of almost every column is skewed.

# %%
df.skew()
# Out:
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.483327
# type             0.000329
# year             0.215339
# region           0.000030
# dtype: float64

# %%
df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
skew=('Total Volume', '4046', '4225', '4770',
       'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags','year')
for col in skew:
    if df.skew().loc[col]>0.55:
        df[col]=np.log1p(df[col])

# %%
df.skew()
# Out:
# AveragePrice    0.580303
# Total Volume    0.088098
# 4046           -0.328195
# 4225           -0.486654
# 4770            0.099986
# Total Bags     -0.218874
# Small Bags     -0.622148
# Large Bags     -0.547765
# XLarge Bags    -1.740681
# type            0.000329
# year            0.215339
# region          0.000030
# dtype: float64

# %%
df.skew()[np.abs(df.skew())<.25].all()
# Out:
# True

# %%
df.hist(figsize=(20,20),grid=True,layout=(4,5))
# Out:
# array([[<AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'AveragePrice'}>,
#         <AxesSubplot:title={'center':'Total Volume'}>,
#         <AxesSubplot:title={'center':'4046'}>,
#         <AxesSubplot:title={'center':'4225'}>],
#        [<AxesSubplot:title={'center':'4770'}>,
#         <AxesSubplot:title={'center':'Total Bags'}>,
#         <AxesSubplot:title={'center':'Small Bags'}>,
#         <AxesSubplot:title={'center':'Large Bags'}>,
#         <AxesSubplot:title={'center':'XLarge Bags'}>],
#        [<AxesSubplot:title={'center':'type'}>,
#         <AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'region'}>, <AxesSubplot:>,
#         <AxesSubplot:>],
#        [<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.plot(kind='box',subplots=True,figsize=(15,15),layout=(4,5))
# Out:
# AveragePrice        AxesSubplot(0.125,0.71587;0.133621x0.16413)
# Total Volume     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# 4046              AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4225             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# 4770             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Total Bags         AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Small Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Large Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# type            AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# year               AxesSubplot(0.125,0.321957;0.133621x0.16413)
# region          AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# dtype: object

# %%
#Skewness is removed 

#Outlier Removal

# %%
#Calculate Zscore and IQR values
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import zscore
import numpy as np
drop_df = df.drop(columns=['Date'])
df = df[(np.abs(zscore(drop_df)) < 3).all(axis=1)]

# %%
df
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     2015-12-27          1.33     11.070344  6.944801  10.905146  3.895080
# 1     2015-12-20          1.35     10.912867  6.515127  10.706381  4.083115
# 2     2015-12-13          0.93     11.680313  6.679222  11.600485  4.879007
# 3     2015-12-06          1.08     11.277116  7.032624  11.184108  4.298373
# 4     2015-11-29          1.28     10.840377  6.848515  10.688288  4.340944
# ...          ...           ...           ...       ...        ...       ...
# 18244 2018-02-04          1.63      9.745419  7.624599   7.333154  0.000000
# 18245 2018-01-28          1.71      9.538855  7.083975   8.141044  0.000000
# 18246 2018-01-21          1.87      9.530085  7.084159   7.805389  6.591591
# 18247 2018-01-14          1.93      9.693150  7.332127   8.000363  6.590315
# 18248 2018-01-07          1.62      9.769418  7.971006   7.765200  5.418453
#
# ...

# %%
df.shape
# Out:
# (16710, 13)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df.plot(kind='box',subplots=True,figsize=(15,15),layout=(4,5))
# Out:
# AveragePrice        AxesSubplot(0.125,0.71587;0.133621x0.16413)
# Total Volume     AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# 4046              AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# 4225             AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# 4770             AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# Total Bags         AxesSubplot(0.125,0.518913;0.133621x0.16413)
# Small Bags      AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# Large Bags       AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# XLarge Bags     AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# type            AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# year               AxesSubplot(0.125,0.321957;0.133621x0.16413)
# region          AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# dtype: object

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1    #IQR is interquartile range. 

drop_df = df.drop(columns=['Date'])
#df = df[(np.abs(zscore(drop_df)) < 3).all(axis=1)]

print(drop_df>(Q1-1.5 *IQR))
print(drop_df<(Q3 + 1.5 *IQR))
# Out:
#        AveragePrice  Total Volume  4046  4225  4770  Total Bags  Small Bags  \
# 0              True          True  True  True  True        True        True
# 1              True          True  True  True  True        True        True
# 2              True          True  True  True  True        True        True
# 3              True          True  True  True  True        True        True
# 4              True          True  True  True  True        True        True
# ...             ...           ...   ...   ...   ...         ...         ...
# 18244          True          True  True  True  True        True        True
# 18245          True          True  True  True  True        True        True
# 18246          True          True  True  True  True        True        True
# 18247          True          True  True  True  True        True        True
# 18248          True          True  True  True  True        True        True
#
#        Large Bags  XLarge Bags  type  year  region
# ...

# %%
df_cleared_iqr = drop_df[~((drop_df < (Q1 - 1.5 * IQR)) |(drop_df > (Q3 + 1.5 * IQR))).any(axis=1)]
df_cleared_iqr
# Out:
#        AveragePrice  Total Volume      4046       4225      4770  Total Bags  \
# 0              1.33     11.070344  6.944801  10.905146  3.895080    9.070833
# 1              1.35     10.912867  6.515127  10.706381  4.083115    9.159737
# 2              0.93     11.680313  6.679222  11.600485  4.879007    9.005325
# 3              1.08     11.277116  7.032624  11.184108  4.298373    8.667708
# 4              1.28     10.840377  6.848515  10.688288  4.340944    8.729874
# ...             ...           ...       ...        ...       ...         ...
# 18244          1.63      9.745419  7.624599   7.333154  0.000000    9.510421
# 18245          1.71      9.538855  7.083975   8.141044  0.000000    9.134090
# 18246          1.87      9.530085  7.084159   7.805389  6.591591    9.147945
# 18247          1.93      9.693150  7.332127   8.000363  6.590315    9.302969
# 18248          1.62      9.769418  7.971006   7.765200  5.418453    9.393924
#
# ...

# %%
df.reindex()
# Out:
#             Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0     2015-12-27          1.33     11.070344  6.944801  10.905146  3.895080
# 1     2015-12-20          1.35     10.912867  6.515127  10.706381  4.083115
# 2     2015-12-13          0.93     11.680313  6.679222  11.600485  4.879007
# 3     2015-12-06          1.08     11.277116  7.032624  11.184108  4.298373
# 4     2015-11-29          1.28     10.840377  6.848515  10.688288  4.340944
# ...          ...           ...           ...       ...        ...       ...
# 18244 2018-02-04          1.63      9.745419  7.624599   7.333154  0.000000
# 18245 2018-01-28          1.71      9.538855  7.083975   8.141044  0.000000
# 18246 2018-01-21          1.87      9.530085  7.084159   7.805389  6.591591
# 18247 2018-01-14          1.93      9.693150  7.332127   8.000363  6.590315
# 18248 2018-01-07          1.62      9.769418  7.971006   7.765200  5.418453
#
# ...

# %%
#Heat map for features correlation

plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black")
# Out:
# <AxesSubplot:>

# %%
#Total bags is having highest correlation with Total Volume,Small Bags. It suggests multicollinearity.
#We can retain any one of the columns for best prediction.

# %%
#Scaling the Data using Min-Max Scaler

from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

#X1= X.select_dtypes(include=['float64'])
drop_df = df.drop(columns=['Date'])


# Variance Inflation Factor

from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
scaler=StandardScaler()
X_scaled = scaler.fit_transform(drop_df)
X_scaled.shape[1]
# Out:
# 12

# %%
vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif["features"]=drop_df.columns

vif
# Out:
#           vif      features
# 0    2.162716  AveragePrice
# 1   53.962830  Total Volume
# 2    6.276171          4046
# 3   10.375540          4225
# 4    4.079939          4770
# 5   33.690793    Total Bags
# 6   16.549990    Small Bags
# 7    3.102422    Large Bags
# 8    1.077366   XLarge Bags
# 9    3.927579          type
# 10   1.367708          year
# 11   1.093292        region

# %%
df.columns
#df["AveragePrice"].unique()
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
X=df[['4046', '4225', '4770',
       'Total Bags', 'Small Bags', 'Large Bags', 'type', 'year',
       'region']]
Y=df["AveragePrice"]
X
# Out:
#            4046       4225      4770  Total Bags  Small Bags  Large Bags  \
# 0      6.944801  10.905146  3.895080    9.070833    9.060055    4.545951
# 1      6.515127  10.706381  4.083115    9.159737    9.149429    4.589955
# 2      6.679222  11.600485  4.879007    9.005325    8.992584    4.645736
# 3      7.032624  11.184108  4.298373    8.667708    8.644425    4.903495
# 4      6.848515  10.688288  4.340944    8.729874    8.697389    5.291746
# ...         ...        ...       ...         ...         ...         ...
# 18244  7.624599   7.333154  0.000000    9.510421    9.477908    6.070391
# 18245  7.083975   8.141044  0.000000    9.134090    9.098407    5.786284
# 18246  7.084159   7.805389  6.591591    9.147945    9.143431    3.768384
# 18247  7.332127   8.000363  6.590315    9.302969    9.298401    3.931826
# 18248  7.971006   7.765200  5.418453    9.393924    9.391757    3.296207
#
#        type  year  region
# 0         0  2015       0
# 1         0  2015       0
# ...

# %%
for i in range(1,100):
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=i)
    lr.fit(X_train,Y_train)
    pred_train=lr.predict(X_train)
    pred_test=lr.predict(X_test)
    
    print(f"At random state {i}, the training accuracy is : {r2_score(Y_train,pred_train)}")
    print(f"At random state {i}, the testing accuracy is : {r2_score(Y_test,pred_test)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is : 0.525438620150592
# At random state 1, the testing accuracy is : 0.52274924044436
#
#
# At random state 2, the training accuracy is : 0.5251757250342128
# At random state 2, the testing accuracy is : 0.5239215866076818
#
#
# At random state 3, the training accuracy is : 0.5215337231878199
# At random state 3, the testing accuracy is : 0.5346172192408604
#
#
# At random state 4, the training accuracy is : 0.5241384737565858
# At random state 4, the testing accuracy is : 0.5266509808856622
#
#
# At random state 5, the training accuracy is : 0.5235253666155316
# At random state 5, the testing accuracy is : 0.5285539604190719
#
#
# At random state 6, the training accuracy is : 0.525076415970176
# At random state 6, the testing accuracy is : 0.5240903849223687
#
#
# At random state 7, the training accuracy is : 0.5264363616894511
# At random state 7, the testing accuracy is : 0.5198925732291604
#
#
# ...

# %%
Testingaccuracy=r2_score(Y_test,pred_test)

from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(lr,X,Y,cv=5)
cv_mean=cv_score.mean()
print(f"the cv_score is {cv_mean}, Test accuracy{Testingaccuracy}")
# Out:
# the cv_score is 0.16607630591226324, Test accuracy0.5254124496052235

# %%
plt.scatter(Y_test,pred_test)
plt.xlabel('Average Price')
plt.ylabel('Predicted Price')
plt.show()

# %%
#Regularisation
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV
from sklearn.model_selection import GridSearchCV,cross_val_score
import warnings
warnings.filterwarnings('ignore')

parameters={'alpha':[.001,.01,-1,1,10]}
lasso=Lasso()
clf=GridSearchCV(lasso,parameters)
clf.fit(X_train,Y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.001}

# %%
lassocv=LassoCV(alphas=None,max_iter=100,normalize=True)
lassocv.fit(X_train,Y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
alpha=lassocv.alpha_
alpha
# Out:
# 2.1630729462126828e-06

# %%
lassoreg=Lasso(alpha)
lassoreg.fit(X_train,Y_train)
# Out:
# Lasso(alpha=2.1630729462126828e-06)

# %%
lassoreg.score(X_test,Y_test)
# Out:
# 0.5269302962505096

# %%
def print_score(clf,X_train,X_test,Y_train,Y_test,train=True):
    if train:
        pred=clf.predict(X_train)

        print(r2_score(pred,X_test))
    
    elif train==False:
        pred=clf.predict(Y_test)
           
        print(r2_score(pred,Y_test))

# %%
X_test.shape
# Out:
# (4178, 10)

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
import pandas as pd
dt_reg=DecisionTreeRegressor()
dt_reg.fit(X_train.values.reshape(-1,1),Y_train.values.reshape(-1,1))
dt_reg.score(X_train,Y_train)
pred=dt_reg.predict(X_test)

dt_reg.score(Y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12084/1050740580.py in <module>
#       3 import pandas as pd
#       4 dt_reg=DecisionTreeRegressor()
# ----> 5 dt_reg.fit(X_train.values.reshape(-1,1),Y_train.values.reshape(-1,1))
#       6 dt_reg.score(X_train,Y_train)
#       7 pred=dt_reg.predict(X_test)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1250         """
#    1251
# -> 1252         super().fit(
#    1253             X, y,
#    1254             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     280
#     281         if len(y) != n_samples:
# --> 282             raise ValueError("Number of labels=%d does not match "
# ...

# %%
# HyperparameterTuning

from sklearn.model_selection import GridSearchCV

grid_param={ 
    'criterion':['gini','entropy'],
    'max_depth':range(10,15),
    'min_samples_leaf':range(2,10,2),
    'min_samples_split': range(3,10),
    'max_leaf_nodes':range(2,4)
    }

grid_search=GridSearchCV(estimator=dt_reg,param_grid=grid_param,cv=5)
grid_search.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12084/1717561424.py in <module>
#      12
#      13 grid_search=GridSearchCV(estimator=dt_reg,param_grid=grid_param,cv=5)
# ---> 14 grid_search.fit(X_train,Y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
# ...

# %%
best_params=grid_search.best_params_
best_params
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'max_leaf_nodes': 2,
#  'min_samples_leaf': 2,
#  'min_samples_split': 3}

# %%
dt_reg=DecisionTreeRegressor(best_params)
dt_reg.fit(X_train.values.reshape(-1,1),Y_train.values.reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12084/37976751.py in <module>
#       1 dt_reg=DecisionTreeRegressor(best_params)
# ----> 2 dt_reg.fit(X_train.values.reshape(-1,1),Y_train.values.reshape(-1,1))
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1250         """
#    1251
# -> 1252         super().fit(
#    1253             X, y,
#    1254             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     280
#     281         if len(y) != n_samples:
# --> 282             raise ValueError("Number of labels=%d does not match "
#     283                              "number of samples=%d" % (len(y), n_samples))
# ...

# %%
#I have updated myself about the regression and classification models and have been trying to work with the dataset. 
#Somehow I'm not able to clear the above error. Please guide me where I've gone wrong.Thank you.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor

model=[DecisionTreeRegressor(),KNeighborsRegressor(),LinearRegression(),AdaBoostRegressor(),GradientBoostingRegressor()]
max_r2=0
for rstate in range(40,90):
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=rstate)
    for i in model:
        i.fit(X_train,Y_train)
        pred_train=i.predict(X_train)
        pred_test=i.predict(X_test)
        r2=r2_score(Y_test,pred_test)
        print("R2 score correspond to Random state", rstate,"is", r2)
        if r2>max_r2:
                    max_r2=r2
                    finalstate=rstate
                    finalmodel=i
print("Max R2score correspond to randomstate", finalstate, "is", max_r2, "and the model is",finalmodel )
# Out:
# R2 score correspond to Random state 40 is 0.6509292340744536
# R2 score correspond to Random state 40 is 0.8205718973129785
# R2 score correspond to Random state 40 is 0.509223906682098
# R2 score correspond to Random state 40 is 0.48549096554086124
# R2 score correspond to Random state 40 is 0.6690332105097851
# R2 score correspond to Random state 41 is 0.6499826276823242
# R2 score correspond to Random state 41 is 0.8219050393277211
# R2 score correspond to Random state 41 is 0.5225587043717405
# R2 score correspond to Random state 41 is 0.4915274938813783
# R2 score correspond to Random state 41 is 0.6800392004482754
# R2 score correspond to Random state 42 is 0.6792777871969287
# R2 score correspond to Random state 42 is 0.8302663136103765
# R2 score correspond to Random state 42 is 0.5432239963231319
# R2 score correspond to Random state 42 is 0.5086319401367916
# R2 score correspond to Random state 42 is 0.6910567989101266
# ...

# %%
#Hyperparameter Tuning

KNN=KNeighborsRegressor()
parameters={'n_neighbors': range(1,30)}
grid_search=GridSearchCV(KNN,parameters)
grid_search.fit(X_train,Y_train)
best_params=grid_search.best_params_
best_params
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12084/3191489591.py in <module>
#       4 parameters={'n_neighbors': range(1,30)}
#       5 grid_search=GridSearchCV(KNN,parameters)
# ----> 6 grid_search.fit(X_train,Y_train)
#       7 best_params=grid_search.best_params_
#       8 best_params
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
# ...

# %%
KNN=KNeighborsRegressor(n_neighbors=3)
KNN.fit(X_train,Y_train)
pred=KNN.predict(X_test)
r2=r2_score(Y_test,pred)
r2
# Out:
# 0.7823384970404803

# %%
#Cross Validation
Testingaccuracy=r2_score(Y_test,pred)

from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(KNN,X,Y,cv=5)
cv_mean=cv_score.mean()
print(f"the cv_score is {cv_mean}, Test accuracy{Testingaccuracy}")
# Out:
# the cv_score is 0.030717143669729906, Test accuracy0.8216202297198537

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error 
import pandas as pd
MAE= mean_absolute_error(Y_test,pred)
print("Mean Absolute Error:",MAE)

MSE=mean_squared_error(Y_test,pred)
print("Mean Squared Error:",MSE)

print("Root Mean Squared Error:", np.sqrt(mean_squared_error(Y_test,pred)))
# Out:
# Mean Absolute Error: 0.11163433061347838
# Mean Squared Error: 0.026002004633826938
# Root Mean Squared Error: 0.16125137095177497

# %%
plt.scatter(Y_test,pred)
plt.xlabel('Average Price')
plt.ylabel('Predicted Price')
plt.show()

# %% [markdown]
# # Classification

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier

df.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
X=df[['AveragePrice', 'Total Volume', '4046', '4225', '4770',
       'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year']]
Y=df['region']
Y.shape
X.shape
# Out:
# (16710, 11)

# %%
from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_scaled.shape[1]

vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif["features"]=X.columns

vif
# Out:
#           vif      features
# 0    2.159738  AveragePrice
# 1   53.807320  Total Volume
# 2    6.021019          4046
# 3   10.374614          4225
# 4    4.078331          4770
# 5   33.612454    Total Bags
# 6   16.549628    Small Bags
# 7    3.099587    Large Bags
# 8    1.074651   XLarge Bags
# 9    3.872297          type
# 10   1.366541          year

# %%
X=df[['AveragePrice', '4046', '4225', '4770',
       'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year']]
Y=df['region']

# %%
model=[DecisionTreeClassifier(),KNeighborsClassifier()]
max_score=0
for rstate in range(40,90):
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=rstate)
    for i in model:
        i.fit(X_train,Y_train)
        pred_train=i.predict(X_train)
        pred_test=i.predict(X_test)
        ac_sc=accuracy_score(Y_test,pred_test)
        print("Accuracy score correspond to Random state", rstate,"is", ac_sc)
        if ac_sc>max_score:
                    max_score=ac_sc
                    finalstate=rstate
                    finalmodel=i
print("Max R2score correspond to randomstate", finalstate, "is", max_r2, "and the model is",finalmodel )
# Out:
# Accuracy score correspond to Random state 40 is 0.785131459655485
# Accuracy score correspond to Random state 40 is 0.8484134179510426
# Accuracy score correspond to Random state 41 is 0.7882139619220309
# Accuracy score correspond to Random state 41 is 0.8357207615593835
# Accuracy score correspond to Random state 42 is 0.7807796917497734
# Accuracy score correspond to Random state 42 is 0.8355394378966455
# Accuracy score correspond to Random state 43 is 0.7963735267452402
# Accuracy score correspond to Random state 43 is 0.8480507706255667
# Accuracy score correspond to Random state 44 is 0.7831368993653672
# Accuracy score correspond to Random state 44 is 0.842067089755213
# Accuracy score correspond to Random state 45 is 0.7782411604714415
# Accuracy score correspond to Random state 45 is 0.8377153218495014
# Accuracy score correspond to Random state 46 is 0.7894832275611967
# Accuracy score correspond to Random state 46 is 0.843155031731641
# ...

# %%
#Hyperparameter Tuning

KNN=KNeighborsClassifier()
parameters={'n_neighbors': range(1,30)}
grid_search=GridSearchCV(KNN,parameters)
grid_search.fit(X_train,Y_train)
best_params=grid_search.best_params_
best_params
# Out:
# {'n_neighbors': 1}

# %%
KNN=KNeighborsRegressor(n_neighbors=1)
KNN.fit(X_train,Y_train)
pred=KNN.predict(X_test)
ac_sc=accuracy_score(Y_test,pred)
accuracy_score
# Out:
# <function sklearn.metrics._classification.accuracy_score(y_true, y_pred, *, normalize=True, sample_weight=None)>

# %% [raw]
# fpr,tpr,thresholds=roc_curve(Y_test,pred,pos_label=True)

# %%
#Cross Validation
Testingaccuracy=accuracy_score(Y_test,pred)

from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(KNN,X,Y,cv=5)
cv_mean=cv_score.mean()
print(f"the cv_score is {cv_mean}, Test accuracy{Testingaccuracy}")
# Out:
# the cv_score is -0.5825351279317154, Test accuracy0.8669084315503173

# %%
plt.scatter(Y_test,pred)
plt.xlabel('Actual Region')
plt.ylabel('Predicted Region')
plt.show()

# %%
# Both for Regression and Classification,Kneighbors models have given the highest scores.
