# %% [markdown]
# # BaseBall Case Study

# %%
import pandas as pd
import numpy as np
import csv

df=pd.read_csv("C:/Users/hp/Downloads/Data-Science-ML-Capstone-Projects-master/baseball.csv")
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %%
df.isnull().sum()
# Out:
# Wins(W)                     0
# Runs                        0
# At Bats                     0
# Hits                        0
# Doubles                     0
# Triples                     0
# Homeruns                    0
# Walks                       0
# Strikeouts                  0
# Stolen Bases                0
# Runs Allowed                0
# Earned Runs                 0
# Earned Run Average (ERA)    0
# Complete Games              0
# Shutouts                    0
# Saves                       0
# Errors                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.columns= ['Wins(W)', 'Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns', 'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs', 'Earned Run Average (ERA)', 'Complete Games','Shutouts', 'Saves', 'Errors']
df.head()
# Out:
#    Wins(W)  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  \
# 0       95   724     5575  1497      300       42       139    383
# 1       83   696     5467  1349      277       44       156    439
# 2       81   669     5439  1395      303       29       141    533
# 3       76   622     5533  1381      260       27       136    404
# 4       74   689     5605  1515      289       49       151    455
#
#    Strikeouts  Stolen Bases  Runs Allowed  Earned Runs  \
# 0         973           104           641          601
# 1        1264            70           700          653
# 2        1157            86           640          584
# 3        1231            68           701          643
# 4        1259            83           803          746
#
#    Earned Run Average (ERA)  Complete Games  Shutouts  Saves  Errors
# 0                      3.73               2         8     56      88
# 1                      4.07               2        12     45      86
# ...

# %% [markdown]
# # Data Preprocessing

# %%
df_visualisation_continuous=df[['Runs', 'At Bats', 'Hits', 'Doubles', 'Triples', 'Homeruns', 'Walks', 'Strikeouts', 'Stolen Bases', 'Runs Allowed', 'Earned Runs', 'Earned Run Average (ERA)', 'Complete Games','Shutouts', 'Saves', 'Errors']].copy()

# %%
df.describe()
# Out:
#           Wins(W)        Runs      At Bats         Hits     Doubles  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#          Triples    Homeruns       Walks  Strikeouts  Stolen Bases  \
# count  30.000000   30.000000   30.000000    30.00000     30.000000
# mean   31.300000  163.633333  469.100000  1248.20000     83.500000
# std    10.452355   31.823309   57.053725   103.75947     22.815225
# min    13.000000  100.000000  375.000000   973.00000     44.000000
# ...

# %%
import matplotlib.pyplot as plt 
plt.hist(df['Wins(W)'])
plt.xlabel('Wins')
plt.title('Distribution of Wins')

plt.show()

# %%
plt.figure(figsize=(20,25))
plotnumber=1

for column in df:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.histplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
import seaborn as sns
sns.distplot(df_visualisation_continuous['Runs'],kde=True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Runs', ylabel='Density'>

# %%
sns.distplot(df_visualisation_continuous['At Bats'],kde=True)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='At Bats', ylabel='Density'>

# %% [markdown]
# # Outlier Detection

# %%
plt.figure(figsize=(20,25))
plotnumber=1

for column in df:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        sns.boxplot(data=df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
df.shape
# Out:
# (30, 17)

# %%
plt.figure(figsize=(20,25))
plotnumber=1

for column in df:
    if plotnumber<=16:
        ax=plt.subplot(4,4,plotnumber)
        plt.scatter(y=df['Wins(W)'],x=df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.show()

# %%
plt.figure(figsize=(20,5))
for column in df:    
    plt.subplot(1,3,2)
    sns.regplot(x=column,y='Wins(W)',data=df)
    plt.show()

# %%
df.corr()
# Out:
#                            Wins(W)      Runs   At Bats      Hits   Doubles  \
# Wins(W)                   1.000000  0.430751 -0.087947  0.037612  0.427797
# Runs                      0.430751  1.000000  0.319464  0.482856  0.560084
# At Bats                  -0.087947  0.319464  1.000000  0.739122  0.453370
# Hits                      0.037612  0.482856  0.739122  1.000000  0.566847
# Doubles                   0.427797  0.560084  0.453370  0.566847  1.000000
# Triples                  -0.251118 -0.070072  0.435422  0.478694  0.220490
# Homeruns                  0.307407  0.671283 -0.066983 -0.090855  0.056292
# Walks                     0.484342  0.402452 -0.136414 -0.118281  0.302700
# Strikeouts                0.111850 -0.054726 -0.106022 -0.398830 -0.150752
# Stolen Bases             -0.157234  0.081367  0.372618  0.413444  0.195027
# Runs Allowed             -0.812952 -0.041623  0.316010  0.224324 -0.218160
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor="black")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black")
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# Wins(W)                     0.047089
# Runs                        1.200786
# At Bats                     0.183437
# Hits                        0.670254
# Doubles                    -0.230650
# Triples                     0.129502
# Homeruns                    0.516441
# Walks                       0.158498
# Strikeouts                 -0.156065
# Stolen Bases                0.479893
# Runs Allowed                0.045734
# Earned Runs                 0.058710
# Earned Run Average (ERA)    0.053331
# Complete Games              0.736845
# Shutouts                    0.565790
# Saves                       0.657524
# Errors                      0.890132
# dtype: float64

# %% [markdown]
# #Outlier Removal

# %%
df.shape
# Out:
# (30, 17)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshhold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#     Wins(W)  Runs  At Bats  Hits  Doubles  Triples  Homeruns  Walks  \
# 0        95   724     5575  1497      300       42       139    383
# 1        83   696     5467  1349      277       44       156    439
# 2        81   669     5439  1395      303       29       141    533
# 3        76   622     5533  1381      260       27       136    404
# 4        74   689     5605  1515      289       49       151    455
# 6        87   764     5567  1397      272       19       212    554
# 7        81   713     5485  1370      246       20       217    418
# 8        80   644     5485  1383      278       32       167    436
# 9        78   748     5640  1495      294       33       161    478
# 10       88   751     5511  1419      279       32       172    503
# 11       86   729     5459  1363      278       26       230    486
# 12       85   661     5417  1331      243       21       176    435
# 13       76   656     5544  1379      262       22       198    478
# ...

# %%
df_new_z.shape
# Out:
# (29, 17)

# %%
X=df.drop(["Wins(W)","Runs Allowed", "Earned Runs","Homeruns"],axis=1)
Y=df["Wins(W)"]

# %%
#Scaling the Data using Min-Max Scaler

from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')


# Variance Inflation Factor

from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_scaled.shape[1]

vif=pd.DataFrame()
vif["vif"]=[variance_inflation_factor(X_scaled,i) for i in range(X_scaled.shape[1])]
vif["features"]=X.columns

vif
# Out:
#          vif                  features
# 0   2.649892                      Runs
# 1   3.734992                   At Bats
# 2   6.410839                      Hits
# 3   3.355030                   Doubles
# 4   2.674741                   Triples
# 5   3.175305                     Walks
# 6   1.678478                Strikeouts
# 7   1.767282              Stolen Bases
# 8   4.603665  Earned Run Average (ERA)
# 9   2.395008            Complete Games
# 10  3.145366                  Shutouts
# 11  2.612783                     Saves
# 12  1.432125                    Errors

# %%
for i in range(1,100):
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=i)
    lr.fit(X_train,Y_train)
    pred_train=lr.predict(X_train)
    pred_test=lr.predict(X_test)
    
    print(f"At random state {i}, the training accuracy is : {r2_score(Y_train,pred_train)}")
    print(f"At random state {i}, the testing accuracy is : {r2_score(Y_test,pred_test)}")
    print("\n")
# Out:
# At random state 1, the training accuracy is : 0.9612730629347451
# At random state 1, the testing accuracy is : 0.6363145803426851
#
#
# At random state 2, the training accuracy is : 0.9690614141056418
# At random state 2, the testing accuracy is : 0.23298472983112217
#
#
# At random state 3, the training accuracy is : 0.9684346124749887
# At random state 3, the testing accuracy is : 0.4632282516213926
#
#
# At random state 4, the training accuracy is : 0.9278461266389006
# At random state 4, the testing accuracy is : 0.8739738599871856
#
#
# At random state 5, the training accuracy is : 0.9307654269869583
# At random state 5, the testing accuracy is : 0.8871851180910966
#
#
# At random state 6, the training accuracy is : 0.9222169476176887
# At random state 6, the testing accuracy is : 0.9495387752352302
#
#
# At random state 7, the training accuracy is : 0.9394679488641243
# At random state 7, the testing accuracy is : 0.4737058167753486
#
#
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X_scaled,Y,test_size=0.2,random_state=68)
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(X_test)
pred_test
# Out:
# array([63.89607437, 72.59447575, 68.54693635, 86.98090165, 81.20025461,
#        91.8173778 ])

# %%
lr.score(X_test,Y_test)
# Out:
# 0.9669311999674307

# %%
print(r2_score(Y_test,pred_test))
# Out:
# 0.9669311999674307

# %%
#CrossValidation of the Model
#Trainingaccuracy=r2_score(Y_train,pred_train)
Testingaccuracy=r2_score(Y_test,pred_test)

from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(lr,X,Y,cv=4)
cv_mean=cv_score.mean()
print(f"the cv_score is {cv_mean}, Test accuracy{Testingaccuracy}")
# Out:
# the cv_score is 0.6954912872938407, Test accuracy0.9669311999674307

# %%
plt.scatter(Y_test,pred_test)
plt.xlabel('Actual Wins')
plt.ylabel('Predicted Wins')
plt.show()

# %%
#Regularisation
from sklearn.linear_model import Ridge,Lasso,RidgeCV,LassoCV
from sklearn.model_selection import GridSearchCV,cross_val_score
import warnings
warnings.filterwarnings('ignore')

parameters={'alpha':[.001,.01,-1,1,10]}
lasso=Lasso()
clf=GridSearchCV(lasso,parameters)
clf.fit(X_train,Y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1}

# %%
lassocv=LassoCV(alphas=None,max_iter=100,normalize=True)
lassocv.fit(X_train,Y_train)
# Out:
# LassoCV(max_iter=100, normalize=True)

# %%
alpha=lassocv.alpha_
alpha
# Out:
# 0.2274435822671309

# %%
lassoreg=Lasso(alpha)
lassoreg.fit(X_train,Y_train)
# Out:
# Lasso(alpha=0.2274435822671309)

# %%
lassoreg.score(X_test,Y_test)
# Out:
# 0.9258323473704761

# %%
#CrossValidation of the Model
#Trainingaccuracy=r2_score(Y_train,pred_train)
Testingaccuracy=r2_score(Y_test,pred_test)

from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(lassoreg,X,Y,cv=3)
cv_mean=cv_score.mean()
print(f" the cv_score is {cv_mean}, Test accuracy{Testingaccuracy}")
# Out:
#  the cv_score is 0.07629516624565684, Test accuracy0.9669311999674307

# %%
#Ridge CV

ridgecv=RidgeCV(alphas=np.arange(0.001,0.1,0.1),normalize=True)
ridgecv.fit(X_train,Y_train)
# Out:
# RidgeCV(alphas=array([0.001]), normalize=True)

# %%
ridgecv.alpha_
# Out:
# 0.001

# %%
ridge_model=Ridge(alpha=ridgecv.alpha_)
ridge_model.fit(X_train,Y_train)
# Out:
# Ridge(alpha=0.001)

# %%
ridge_model.score(X_test,Y_test)
# Out:
# 0.9669196613074014

# %%
#CrossValidation of the Model
#Trainingaccuracy=r2_score(Y_train,pred_train)
Testingaccuracy=r2_score(Y_test,pred_test)

from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(ridge_model,X,Y,cv=7)
cv_mean=cv_score.mean()
print(f" the cv_score is {cv_mean}, Test accuracy{Testingaccuracy}")


#With Ridge Regression, the score is high so we use Ridge regression for this dataset.
# Out:
#  the cv_score is 0.5112621270571527, Test accuracy0.9669311999674307

# %%
def print_score(clf,X_train,X_test,Y_train,Y_test,train=True):
    if train:
        pred=clf.predict(X_train)

    
        print(r2_score(pred,X_test))
    
    elif train==False:
        pred=clf.predict(Y_test)
           
        print(r2_score(pred,Y_test))

# %%
#Gradient Boost Classifier                    
                    
from sklearn.ensemble import GradientBoostingClassifier
gbdt=GradientBoostingClassifier()
gbdt.fit(X_train,Y_train)
print_score(gbdt,X_train,X_test,Y_train,Y_test,train=True)  
print_score(gbdt,X_train,X_test,Y_train,Y_test,train=False)
# Out:
# -1.0229980115775867
# -1.1632231404958677

# %%
#Random Forest Classifier
,
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,Y_train)
print_score(rf,X_train,X_test,Y_train,Y_test,train=True)  
print_score(rf,X_train,X_test,Y_train,Y_test,train=False)
# Out:
# -1.0229980115775867
# -0.2753099173553719

# %%
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
dt_reg=DecisionTreeRegressor()
dt_reg.fit(X_train,Y_train)
dt_reg.score(X_train,Y_train)
#pred=dt_reg.predict(X_test)
# Out:
# 1.0

# %%
# HyperparameterTuning

from sklearn.model_selection import GridSearchCV

grid_param={ 
    'criterion':['gini','entropy'],
    'max_depth':range(10,15),
    'min_samples_leaf':range(2,10,2),
    'min_samples_split': range(3,10),
    'max_leaf_nodes':range(2,4)
    }

grid_search=GridSearchCV(estimator=dt_reg,param_grid=grid_param,cv=5)
grid_search.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11824/404381004.py in <module>
#      12
#      13 grid_search=GridSearchCV(estimator=dt_reg,param_grid=grid_param,cv=5)
# ---> 14 grid_search.fit(X_train,Y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
# ...

# %%
best_params=grid_search.best_params_
best_params
# Out:
# {'max_depth': 10,
#  'max_leaf_nodes': 3,
#  'min_samples_leaf': 4,
#  'min_samples_split': 3}

# %%
dt_reg=DecisionTreeRegressor(best_params)
dt_reg.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11824/633552077.py in <module>
#       1 dt_reg=DecisionTreeRegressor(best_params)
# ----> 2 dt_reg.fit(X_train,Y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1250         """
#    1251
# -> 1252         super().fit(
#    1253             X, y,
#    1254             sample_weight=sample_weight,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     349                                                          self.n_classes_)
#     350             else:
# --> 351                 criterion = CRITERIA_REG[self.criterion](self.n_outputs_,
#     352                                                          n_samples)
#     353         else:
#
# ...
