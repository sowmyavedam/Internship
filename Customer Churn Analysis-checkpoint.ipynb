# %%
import pandas as pd
import numpy as np
import csv

df=pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/DSData/master/Telecom_customer_churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.drop(["customerID"],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.PaymentMethod.unique()
# Out:
# array(['Electronic check', 'Mailed check', 'Bank transfer (automatic)',
#        'Credit card (automatic)'], dtype=object)

# %%
import seaborn as sns
PaymentMethods=df.PaymentMethod.value_counts()
PaymentMethods
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x=PaymentMethods.index,y=PaymentMethods)
plt.ylabel("PaymentMethods")
plt.xlabel("PaymentMethod")
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3]),
#  [Text(0, 0, 'Electronic check'),
#   Text(1, 0, 'Mailed check'),
#   Text(2, 0, 'Bank transfer (automatic)'),
#   Text(3, 0, 'Credit card (automatic)')])

# %%
gender=df.gender.value_counts()
gender
# Out:
# Male      3555
# Female    3488
# Name: gender, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.barplot(x=gender.index,y=gender)
plt.ylabel("Count")
plt.xlabel("gender")
# Out:
# Text(0.5, 0, 'gender')

# %%
churn=df.Churn.value_counts()
churn
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
sns.barplot(x=churn.index,y=churn)
plt.ylabel("Count")
plt.xlabel("Churn")
# Out:
# Text(0.5, 0, 'Churn')

# %%
MultipleLines=df.MultipleLines.value_counts()
MultipleLines

sns.barplot(x=MultipleLines.index,y=MultipleLines)
plt.ylabel("Count")
plt.xlabel("MultipleLines")
# Out:
# Text(0.5, 0, 'MultipleLines')

# %%
sns.countplot(df["MultipleLines"],hue=df["Churn"])
plt.ylabel("Churn")

plt.xlabel("MultipleLines")

plt.legend(MultipleLines.index,loc="upper left")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(df["Contract"],hue=df["Churn"])
plt.ylabel("Churn")
plt.xlabel("Contract")
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 0, 'Contract')

# %%
#Label Encoding
import pandas as pd
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for col in df.columns:
    if df[col].dtypes=="object":
        df[col]=LE.fit_transform(df[col])
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       0              0        1           0       1             0
# 1       1              0        0           0      34             1
# 2       1              0        0           0       2             1
# 3       1              0        0           0      45             0
# 4       0              0        0           0       2             1
#
#    MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# 0              1                0               0             2
# 1              0                0               2             0
# 2              0                0               2             2
# 3              1                0               2             0
# 4              0                1               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  Contract  \
# 0                 0            0            0                0         0
# ...

# %%
plt.figure(figsize=(20,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor="black")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box',subplots=True,figsize=(15,15),layout=(4,5))
# Out:
# gender                  AxesSubplot(0.125,0.71587;0.133621x0.16413)
# SeniorCitizen        AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# Partner               AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# Dependents           AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# tenure               AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# PhoneService           AxesSubplot(0.125,0.518913;0.133621x0.16413)
# MultipleLines       AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# InternetService      AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# OnlineSecurity      AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# OnlineBackup        AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# DeviceProtection       AxesSubplot(0.125,0.321957;0.133621x0.16413)
# TechSupport         AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# StreamingTV          AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# StreamingMovies     AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# ...

# %%
# No outliers found

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
X=df[['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
       'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
       'MonthlyCharges', 'TotalCharges']]
Y=df["Churn"]

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,roc_auc_score,roc_curve
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import AdaBoostClassifier,GradientBoostingClassifier,RandomForestClassifier

from sklearn.preprocessing import StandardScaler
from statsmodels.stats.outliers_influence import variance_inflation_factor
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)
X_scaled.shape[1]
# Out:
# 19

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X_scaled,Y,test_size=0.30,random_state=34)

# %%
model=[DecisionTreeClassifier(),KNeighborsClassifier(),AdaBoostClassifier()]
#model=[GradientBoostingClassifier(),RandomForestClassifier()]
max_score=0
for rstate in range(40,90):
    X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=rstate)
    for i in model:
        i.fit(X_train,Y_train)
        pred_train=i.predict(X_train)
        pred_test=i.predict(X_test)
        ac_sc=accuracy_score(Y_test,pred_test)
        print("Accuracy score correspond to Random state", rstate,"is", ac_sc)
        if ac_sc>max_score:
                    max_score=ac_sc
                    finalstate=rstate
                    finalmodel=i
print("Accuracy score correspond to randomstate", finalstate, "is", max_score, "and the model is",finalmodel )
# Out:
# Accuracy score correspond to Random state 40 is 0.727741935483871
# Accuracy score correspond to Random state 40 is 0.7410752688172043
# Accuracy score correspond to Random state 40 is 0.7866666666666666
# Accuracy score correspond to Random state 41 is 0.7247311827956989
# Accuracy score correspond to Random state 41 is 0.7367741935483871
# Accuracy score correspond to Random state 41 is 0.7961290322580645
# Accuracy score correspond to Random state 42 is 0.7329032258064516
# Accuracy score correspond to Random state 42 is 0.7565591397849463
# Accuracy score correspond to Random state 42 is 0.8073118279569892
# Accuracy score correspond to Random state 43 is 0.7273118279569892
# Accuracy score correspond to Random state 43 is 0.7406451612903225
# Accuracy score correspond to Random state 43 is 0.8025806451612904
# Accuracy score correspond to Random state 44 is 0.7221505376344086
# Accuracy score correspond to Random state 44 is 0.7488172043010752
# ...

# %%
#Accuracy score correspond to randomstate 46 is 0.8129032258064516 and the model is AdaBoostClassifier()
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.33,random_state=46)
abc=AdaBoostClassifier()
abc.fit(X_train,Y_train)
pred_train=abc.predict(X_train)
pred_test=abc.predict(X_test)
ac_sc=accuracy_score(Y_test,pred_test)
print("Accuracy score is", ac_sc)
# Out:
# Accuracy score is 0.8129032258064516

# %%
print(classification_report(Y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88      1725
#            1       0.66      0.57      0.61       600
#
#     accuracy                           0.81      2325
#    macro avg       0.76      0.73      0.74      2325
# weighted avg       0.81      0.81      0.81      2325

# %%
print(confusion_matrix(Y_test,pred_test))
# Out:
# [[1548  177]
#  [ 258  342]]

# %%
#CrossValidation

Testingaccuracy=accuracy_score(Y_test,pred_test)

from sklearn.model_selection import cross_val_score
cv_score=cross_val_score(abc,X,Y,cv=53)
cv_mean=cv_score.mean()
print(f"the cv_score is {cv_mean}, Test accuracy{Testingaccuracy}")
# Out:
# the cv_score is 0.8000930714436179, Test accuracy0.8129032258064516

# %%
#Hyperparameter Tuning

from sklearn.model_selection import GridSearchCV,cross_val_score
import warnings
warnings.filterwarnings('ignore')

model_params= {
    'n_estimators': [100,200,300]
}

clf=GridSearchCV(abc, model_params, n_jobs=-1, cv=5)
model = clf.fit(X,Y)

# %%
# print winning set of hyperparameters
from pprint import pprint
pprint(model.best_estimator_.get_params())
# Out:
# {'algorithm': 'SAMME.R',
#  'base_estimator': None,
#  'learning_rate': 1.0,
#  'n_estimators': 100,
#  'random_state': None}

# %%
model.best_score_
# Out:
# 0.8027829416413962

# %%
model.best_params_
# Out:
# {'n_estimators': 100}

# %%
abc_best=AdaBoostClassifier(n_estimators=100)

# %%
abc_best.fit(X_train,Y_train)
# Out:
# AdaBoostClassifier(n_estimators=100)

# %%
pred_test_abc_best=abc_best.predict(X_test)

# %%
ac_sc=accuracy_score(Y_test,pred_test_abc_best)
print("Accuracy score is", ac_sc)
# Out:
# Accuracy score is 0.8111827956989247

# %%
print(confusion_matrix(Y_test,pred_test_abc_best))
# Out:
# [[1552  173]
#  [ 266  334]]

# %%
import pickle

# %%
file=open('Customer Churn Analysis.pkl','wb')

# %%
pickle.dump(abc_best,file)

# %%
model=open('Customer Churn Analysis.pkl','rb')
LoanApplicationStatus=pickle.load(model)
